# %%
#from sympy import * 
from Prova1 import *
s, k = var('s K')

# %%
nG = [4] 
dG = [1,2,4]

nH = [1]
dH = [1]

Q2 = Prova_1(nG, dG, nH, dH)
Q2.Avanco(Mp = None, Wn = None, Kp = None, csi = None)
# Out:
# 'A função de malha aberta é: '
# TransferFunction(array([4]), array([1, 2, 4]))
# 'A retroalimentação é: '
# TransferFunction(array([1]), array([1]))
# 'A função de malha fechada é: '
# TransferFunction(array([4]), array([1, 2, 8]))

# %%
nG = [4] 
dG = [1,2,4]

nH = [1]
dH = [1]

Q1 = Prova_1(nG, dG, nH, dH)
Q1.LR()
# Out:
# 'A função de malha aberta é: '
# TransferFunction(array([4]), array([1, 2, 4]))
# 'A retroalimentação é: '
# TransferFunction(array([1]), array([1]))
# 'A função de malha fechada é: '
# TransferFunction(array([4]), array([1, 2, 8]))
# Malha aberta G(s)= 4*K**2/(s**2 + 2*s + 4)
# Malha fechada F(s)= 4*K**2/(4*K**2 + s**2 + 2*s + 4)
#
#  Para que a solução seja estável "s" deve ser menor que zero, logo:
#
#  O sistema é estável se: True
#
# Tabela de Routh:
# Matrix([
# [         1, 4*K**2 + 4],
# [         2,          0],
# [4*K**2 + 4,          0]])
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-cf835a40ea52> in <module>
#       6
#       7 Q1 = Prova_1(nG, dG, nH, dH)
# ----> 8 Q1.LR()
#
# ~\OneDrive\Materia de Esdudo do dia\ELT 331\Programas\Prova1.py in LR(self)
#      67         print(" \nTabela de Routh:")
# ...
